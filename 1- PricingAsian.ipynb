# %% [markdown]
# #### Question 2 :
#  On considère dans le modèle de Black & Scholes une option asiatique arithmétique discrète de
#  maturité T et de strike K. On pourra prendre comme valeurs de référence $S_0 = 100$, $K = 100$,
#  $T=1$, $r=0.05$, $σ=0.20$, $d=12$, $N=10^5$.
#  1. Tracer en fonction de S0 sur un même graphe le prix exact du call européen et le prix
#  Monte Carlo de l’option asiatique de mêmes strike et maturité à d dates. Commenter.

# %%
## import cell
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats

# %%
## initialisation des paramètres
S = 100
K = 100
r = 0.05
sigma = 0.2
d = 12
N = int(1e5) # pour plus de rapidité de calcul
nb_prices = 20

# %%
## basic functions
def black_scholes_european_call(S, K, T, r, sigma):
    d1 = (np.log(S / K) + (r + 0.5 * sigma**2) * T) / (sigma * np.sqrt(T))
    d2 = d1 - sigma * np.sqrt(T)
    
    return {'Price' : S * stats.norm.cdf(d1) - K * np.exp(-r * T) * stats.norm.cdf(d2), 'Variance' : 0}

def monte_carlo_asian_call(S, K, T, r, sigma, d, N):
    step = T / d
    simulations = np.zeros((N, d+1))
    simulations[:,0] = S
    for iter in range(N):
        for t in range(1,d+1):
            dx = np.random.normal()
            simulations[iter, t] = simulations[iter, t-1]*np.exp((r - 0.5 * sigma ** 2) * step + sigma * np.sqrt(step) * dx)
    realized_payoff = np.exp(-r * T) * np.maximum(np.mean(simulations[:, 1:], axis=1) - K, 0)
    return {'Price' : np.mean(realized_payoff), 'Variance' : np.var(realized_payoff)}

# %%
### Graphiques exemples
Unders = np.linspace(0.8*K,1.2*K, nb_prices) ## prix du sous-jacent
Maturities = [1] 
colors = plt.get_cmap("tab10").colors

Prices = np.zeros((2*len(Maturities),nb_prices))
for i_T, T in enumerate(Maturities):
    for i, S in enumerate(Unders):
        european = black_scholes_european_call(S,K,T,r,sigma)
        asian = monte_carlo_asian_call(S,K,T,r,sigma,d,N)
        Prices[i_T,i] = european['Price']
        Prices[i_T + 1,i] = asian['Price']
        
    plt.plot(Unders, Prices[i_T,:],color=colors[i_T%len(colors)], markersize=2, label=f'européen T = {T}')
    plt.plot(Unders, Prices[i_T+1,:],color=colors[i_T+1%len(colors)], markersize=2, label=f'asiatique T = {T}')
    
plt.title(f'Call Européen vs Call Asiatique pour les maturités données')
plt.xlabel('Prix du sous-jacent')
plt.ylabel('Prix du Call')
plt.legend()
plt.show()

# %% [markdown]
# Commentaires : C_asian < C_europeen. Le payoff asiatique est plus "lisse" que le classique, donc moins risqué pour l'émetteur du contrat, ce qui réduit la prime.
# On peut églament le voir en disant qu'une forte montée du prix du sous-jacent a une grande probabilité d'arriver après une ou plusieurs dates $t_i$, et le retour à l'investisseur sera amoindri à cause des valeurs précédentes qui entrent en compte. On alloue donc une prime plus faible.
# A l'inverse, si une forte variation à la baisse intervient, les deux options ont un payoff nul, donc cet evènement extrême ne contribue pas au dimensionnement de la prime.
#
# 2)  Prix Monte Carlo de l’option asiatique et l’intervalle de confiance en fonction du nombre de dates d’observations d.

# %%
Unders = np.linspace(0.8*K,1.2*K, nb_prices) ## prix du sous-jacent
Maturities = [1] 
times = [2,4,40]
colors = plt.get_cmap("tab10").colors
alpha = 0.05

def plotting(Unders, Maturities, times, alpha,f):
    eps = 1e-5 ## we add to avoid dividing by 0
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
    Prices = np.zeros((3*len(Maturities),nb_prices,len(times)))
    pct_errors = np.zeros((len(Maturities),nb_prices,len(times)))
    for i_T, T in enumerate(Maturities):
        for i_d, d in enumerate(times):
            for i, S in enumerate(Unders):  
                X = f(S,K,T,r,sigma,d,N)
                
                price = X['Price']
                s2 = X['Variance']
                q_aplha = stats.norm.ppf(1 - alpha / 2)
                
                Prices[i_T*3,i,i_d] = price + np.sqrt(s2/N) * q_aplha
                Prices[i_T*3 + 1,i,i_d] = price
                Prices[i_T*3 + 2,i,i_d] = price - np.sqrt(s2/N) * q_aplha
                
                pct_errors[i_T,i,i_d] = 100 * 2 * np.sqrt(s2/N) * q_aplha / (price+eps)
          
            ax1.plot(Unders, Prices[3*i_T,:, i_d],color=colors[(i_T+i_d)%len(colors)], markersize=2, linestyle='--')
            ax1.plot(Unders, Prices[3*i_T+1,:,i_d],color=colors[(i_T+i_d)%len(colors)], markersize=2, label=f'Asiatique T = {T}, d = {d}')
            ax1.plot(Unders, Prices[3*i_T+2,:,i_d],color=colors[(i_T+i_d)%len(colors)], markersize=2, linestyle='--')
            ax2.scatter(Unders, pct_errors[i_T,:,i_d],color=colors[(i_T+i_d)%len(colors)], s=2, label=f'T = {T}, d = {d}',marker='o')
       
    ax1.set_title(f'Call Asiatique pour les maturités données et intervalles de confiance pour alpha = {alpha}')
    ax1.set_xlabel('Prix du sous-jacent')
    ax1.set_ylabel('Prix du Call')
    ax1.legend()
    
    ax2.set_title(f'Erreur du Call Asiatique en % pour alpha = {alpha}')
    ax2.set_xlabel('Prix du sous-jacent')
    ax2.set_ylabel("Taille de l'intervalle de confiance en % (vs prix estimé)")
    ax2.legend()
    plt.show()

plotting(Unders, Maturities, times, alpha, monte_carlo_asian_call)

# %% [markdown]
# Commentaires : a priori à gauche, il semble que la marge d'erreur reste assez faible pour $N = 10^5$.
# Mais en se plaçant en relatif par rapport au prix de l'option, on constate que le prix réel peut aller jusqu'à +- 1% du prix estimé (à la monnaie), alors même que le nombre d'itérations est déjà elevé et que la maturité n'est pas très lointaine. Ce n'est pas admissible pour un trader. D'où le besoin de contrôler la variance.
#
# Remarque : $d_1 > d_2 => C_1 < C_2$. En effet, davantage de lissage à mesure que $d$ augmente, donc prix moins élevé.

# %% [markdown]
# 3) Calculer le prix de l’option asiatique avec la variable de contrôle $Z = S_T$ (que vaut $E[Z]$ ?). Vérifier que le prix Monte Carlo avec la variable de contrôle est correct.
# Quel est le facteur de réduction de variance obtenu? Estimer par simulation le facteur de réduction théorique
#
# Commentaire : $E(Z) = e^{rT} S_0$ d'après la forme de $S_t$.
# On obtient le facteur de réduction suivant : $\frac{1}{1 - \rho^2_{((\frac{1}{d}\sum_{i=1}^dS_{t_i}- K)_+,S_T)}}$

# %%
def monte_carlo_asian_call_ST(S, K, T, r, sigma, d, N):
    step = T / d
    simulations = np.zeros((N, d+1))
    simulations[:,0] = S
    S_T_simulations = np.zeros(N)
    for iter in range(N):
        for t in range(1,d+1):
            dx = np.random.normal()
            simulations[iter, t] = simulations[iter, t-1]*np.exp((r - 0.5 * sigma ** 2) * step + sigma * np.sqrt(step) * dx)
        S_T_simulations[iter] = simulations[iter,-1]
    
    realized_payoff = np.maximum(np.mean(simulations[:, 1:], axis=1) - K, 0)
        
    # here we can approach the optimal c_star by computing rho(payoff,S_T) :
    cov = np.cov(realized_payoff,S_T_simulations)
    c_star = - cov[0,1]/cov[1,1]
    E_S_T = S * np.exp(r * T)
    
    adj_realized = np.exp(-r * T) * (realized_payoff + c_star * (S_T_simulations - E_S_T))
    return {'Price': np.mean(adj_realized), 'Variance': np.var(adj_realized), 'Corr' : np.corrcoef(realized_payoff,S_T_simulations)}
        
Unders = np.linspace(0.8*K,1.2*K, nb_prices) ## prix du sous-jacent
Maturities = [1] 
colors = plt.get_cmap("tab10").colors
times = [12]
alpha =0.05

plotting(Unders, Maturities,times, alpha,monte_carlo_asian_call_ST)

coeff = 1-monte_carlo_asian_call_ST()['Corr']**2
print(f'Le facteur de réduction de la variance est, après estimation empirique, {np.round(1/coeff[1,0],2)}')
# Out:
# Le facteur de réduction de la variance est, après estimation empirique, 3.03

# %% [markdown]
# Commentaire : on doit théoriquement diviser la variance par 3 environ. Cela reste insuffisant, si l'on souhaite par exemple donner le prix à moins de 5 bp près à la monnaie pour $T=1$, sans augmenter davantage $N$.
#
# 4) On prend désormais $Z_1 = \frac{1}{d}\sum_{i=1}^dS_{t_i}$ puis $Z_2 = (S_T - K)_+$

# %%
def monte_carlo_asian_call_Z1(S, K, T, r, sigma, d, N):
    step = T / d
    simulations = np.zeros((N, d+1))
    simulations[:,0] = S
    for iter in range(N):
        for t in range(1,d+1):
            dx = np.random.normal()
            simulations[iter, t] = simulations[iter, t-1]*np.exp((r - 0.5 * sigma ** 2) * step + sigma * np.sqrt(step) * dx)
    Z = np.mean(simulations[:, 1:], axis=1)
    realized_payoff = np.maximum(np.mean(simulations[:, 1:], axis=1) - K, 0)
        
    # here we can approach the optimal c_star by computing rho(payoff,S_T) :
    cov = np.cov(realized_payoff,Z)
    c_star = - cov[0,1]/cov[1,1]
    E_Z = np.mean(Z)
    
    adj_realized = np.exp(-r * T) * (realized_payoff + c_star * (Z - E_Z))
    return {'Price': np.mean(adj_realized), 'Variance': np.var(adj_realized), 'Corr' : np.corrcoef(realized_payoff,Z)}

plotting(Unders, Maturities,times, alpha,monte_carlo_asian_call_Z1)

coeff = 1-monte_carlo_asian_call_Z1()['Corr']**2
print(f'Le facteur de réduction de la variance est, après estimation empirique, {np.round(1/coeff[1,0],2)}')
# Out:
# Variance reduction factor is, after emprirical estimation, 6.02

# %% [markdown]
# Commentaire : facteur de division > 5, encore mieux. Prévisible car Z ressemble davantage au payoff de l'option asiatique que simplement $S_T$.

# %%
def monte_carlo_asian_call_Z2(S, K, T, r, sigma, d, N):
    step = T / d
    simulations = np.zeros((N, d+1))
    simulations[:,0] = S
    for iter in range(N):
        for t in range(1,d+1):
            dx = np.random.normal()
            simulations[iter, t] = simulations[iter, t-1]*np.exp((r - 0.5 * sigma ** 2) * step + sigma * np.sqrt(step) * dx)
    Z = np.maximum(simulations[:, -1] - K, 0)
    realized_payoff = np.maximum(np.mean(simulations[:, 1:], axis=1) - K, 0)
        
    # here we can approach the optimal c_star by computing rho(payoff,S_T) :
    cov = np.cov(realized_payoff,Z)
    c_star = - cov[0,1]/cov[1,1]
    E_Z = np.mean(Z)
    
    adj_realized = np.exp(-r * T) * (realized_payoff + c_star * (Z - E_Z))
    return {'Price': np.mean(adj_realized), 'Variance': np.var(adj_realized), 'Corr' : np.corrcoef(realized_payoff,Z)}

plotting(Unders, Maturities,times, alpha,monte_carlo_asian_call_Z2)

coeff = 1-monte_carlo_asian_call_Z2()['Corr']**2
print(f'Le facteur de réduction de la variance est, après estimation empirique, {np.round(1/coeff[1,0],2)}')
# Out:
# Le facteur de réduction de la variance est, après estimation empirique, 3.846153846153846

# %% [markdown]
# Un peu moins bon car la variable de réduction de variance ressemble moins au payoff de l'option asiatique.

# %%
def monte_carlo_asian_call_ST_Z1_Z2(S, K, T, r, sigma, d, N):
    step = T / d
    simulations = np.zeros((N, d+1))
    simulations[:,0] = S
    for iter in range(N):
        for t in range(1,d+1):
            dx = np.random.normal()
            simulations[iter, t] = simulations[iter, t-1]*np.exp((r - 0.5 * sigma ** 2) * step + sigma * np.sqrt(step) * dx)
    realized_payoff = np.maximum(np.mean(simulations[:, 1:], axis=1) - K, 0)
    
    ## control variables
    ST = simulations[:, -1]       
    Z1 = np.mean(simulations[:, 1:], axis=1)  
    Z2 = np.maximum(simulations[:, -1] - K, 0)
    #expected values
    E_ST = S * np.exp(r*T)
    E_Z1 = np.mean(Z1)
    E_Z2 = np.mean(Z2)
    
    # this code is not optimal from a memory standing point
    Z = np.array([ST, Z1, Z2]) # shape 3,N
    E_Z = np.array([E_ST, E_Z1, E_Z2]).reshape(3,1) # shape 3
    
    #matrices
    var_Z_inv = np.linalg.inv(np.cov(Z)) # shape (3,3)
    cov_HZ = np.cov(Z,realized_payoff)[:-1,-1] #we keep the last col, H vs each Zi
    
    # here we can approach the optimal c_star by computing rho(payoff,S_T) :
    c_star = - var_Z_inv @ cov_HZ # shape (3,)

    adj_realized = np.exp(-r * T) * (realized_payoff + c_star.T @ (Z - E_Z))
    reduction = cov_HZ.T @ var_Z_inv @ cov_HZ / np.var(realized_payoff)
    
    
    return {'Price': np.mean(adj_realized), 'Variance': np.var(adj_realized), 'Corr' : reduction}

plotting(Unders, Maturities,times, alpha,monte_carlo_asian_call_ST_Z1_Z2)

coeff = 1-monte_carlo_asian_call_ST_Z1_Z2()['Corr']**2
print(f'Le facteur de réduction de la variance est, après estimation empirique, {np.round(1/coeff,2)}')
# Out:
# Le facteur de réduction de la variance est, après estimation empirique, 7.02

# %% [markdown]
# Commentaire : réduction d'un diviseur théorique proche de 7. Si le prix de départ à la monnaie T =1 était estimé à +- 100bp, désormais plutôt +- 14bp. En fonction des besoins de l'émetteur, il faudrait peut-être gagner davantage en précision.

# %% [markdown]
# 6) Reprendre la question 2. pour une option asiatique à moyenne géométrique et vérifier la convergence vers la valeur exacte.

# %%
def monte_carlo_asian_call_geometrique(S, K, T, r, sigma, d, N):
    step = T / d
    simulations = np.zeros((N, d+1))
    simulations[:,0] = S
    for iter in range(N):
        for t in range(1,d+1):
            dx = np.random.normal()
            simulations[iter, t] = simulations[iter, t-1]*np.exp((r - 0.5 * sigma ** 2) * step + sigma * np.sqrt(step) * dx)
    realized_payoff = np.exp(-r * T) * np.maximum(stats.gmean(simulations[:, 1:], axis=1) - K, 0)
    return {'Price' : np.mean(realized_payoff), 'Variance' : np.var(realized_payoff)}

# %%
Unders = np.linspace(0.8*K,1.2*K, nb_prices) ## prix du sous-jacent
Maturities = [1] 
times = [2,4,40]
colors = plt.get_cmap("tab10").colors
alpha = 0.05

def plotting(Unders, Maturities, times, alpha,f):
    eps = 1e-5 ## we add to avoid dividing by 0
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 6))
    Prices = np.zeros((3*len(Maturities),nb_prices,len(times)))
    pct_errors = np.zeros((len(Maturities),nb_prices,len(times)))
    for i_T, T in enumerate(Maturities):
        for i_d, d in enumerate(times):
            for i, S in enumerate(Unders):  
                X = f(S,K,T,r,sigma,d,N)
                
                price = X['Price']
                s2 = X['Variance']
                q_aplha = stats.norm.ppf(1 - alpha / 2)
                
                Prices[i_T*3,i,i_d] = price + np.sqrt(s2/N) * q_aplha
                Prices[i_T*3 + 1,i,i_d] = price
                Prices[i_T*3 + 2,i,i_d] = price - np.sqrt(s2/N) * q_aplha
                
                pct_errors[i_T,i,i_d] = 100 * 2 * np.sqrt(s2/N) * q_aplha / (price+eps)
          
            ax1.plot(Unders, Prices[3*i_T,:, i_d],color=colors[(i_T+i_d)%len(colors)], markersize=2, linestyle='--')
            ax1.plot(Unders, Prices[3*i_T+1,:,i_d],color=colors[(i_T+i_d)%len(colors)], markersize=2, label=f'Asiatique T = {T}, d = {d}')
            ax1.plot(Unders, Prices[3*i_T+2,:,i_d],color=colors[(i_T+i_d)%len(colors)], markersize=2, linestyle='--')
            ax2.scatter(Unders, pct_errors[i_T,:,i_d],color=colors[(i_T+i_d)%len(colors)], s=2, label=f'T = {T}, d = {d}',marker='o')
       
    ax1.set_title(f'Call Asiatique à moyenne géométrique et intervalles de confiance pour alpha = {alpha}')
    ax1.set_xlabel('Prix du sous-jacent')
    ax1.set_ylabel('Prix du Call')
    ax1.legend()
    
    ax2.set_title(f'Erreur du Call Asiatique en % pour alpha = {alpha}')
    ax2.set_xlabel('Prix du sous-jacent')
    ax2.set_ylabel("Taille de l'intervalle de confiance en % (vs prix estimé)")
    ax2.legend()
    plt.show()

plotting(Unders, Maturities, times, alpha, monte_carlo_asian_call_geometrique)

# %% [markdown]
# On peut calculer le prix de l'option asiatique à moyenne géométrique en définissant la moyenne géométrique : $G_T = exp(\frac{1}{T} \int_0^T log(S(t))dt)$. En utilisant $S_T = S_0 exp((r-\frac{\sigma^2}{2})t+\sigma B_t)$, on arrive à $G_T = S_0 exp((r-\frac{\sigma^2}{2})\frac{T}{2})exp(\frac{\sigma}{T} \int_0^T B_tdt)$.
#
# Avec Ito, $d(B_t(T-t))=-B_tdt+(T-t)dB_t$.
# Donc, $G_T = S_0 exp((r-\frac{\sigma^2}{2})\frac{T}{2})exp(\frac{\sigma}{T} \int_0^T (T-t) dB_t)$ car $B_0=0$ donc l'intégration de $d(B_t(T-t))$ entre $t=0$ et $t=T$ disparaît.
#
# En reproduisant le même raisonnement que lors de la démonstration de Black-Scholes soit en discountant l'option et en appliquant l'espérance associée à la mesure martingale équivalente (risque-neutre) conditionnelle par rapport à la filtration engendrée, on arrive au fait que l'option est exprimée si $G_T >= K$.
#
# Soit : $\frac{\sigma}{T} \int_0^T (T-t) dB_t >= log(\frac{K}{S_0})-\frac{1}{2}(r-\frac{\sigma^2}{2})T$.
#
# Comme $Var(\int_0^T (T-t) dB_t) = \int_0^T (T-t)^2 dt = \frac{T^3}{3}$.
# Donc : $\frac{\sigma}{T} \int_0^T (T-t) dB_t = \frac{\sigma}{T}T\sqrt{\frac{T}{3}}x = \sigma\sqrt{\frac{T}{3}}x$ où $x \sim \mathcal{N}(0,1)$.
#
# Alors on peut poser $\sigma_G = \frac{\sigma}{\sqrt{3}}, b = \frac{1}{2}(r-\frac{\sigma^2}{2}), d_1 = \frac{log(\frac{S_0}{K})+(b+\frac{\sigma_G^2}{2})T}{\sigma_G \sqrt{T}}, d_2 = d_1 - \sigma_G \sqrt{T}$.
#
# Le Call asiatique correspondant est alors donné par la formule : $C_T = S_0 e^{(b-r)T}\Phi(d_1)-Ke^{-rT}\Phi(d_2)$, ce que nous allons coder maintenant.

# %%
def asiatique_geometrique_exact_value(S, K, T, r, sigma):
    sigma_G = sigma / np.sqrt(3)
    b = 1/2 * (r - 1/2 * sigma_G**2)
    d1 = (np.log(S / K) + (b + 0.5 * sigma_G**2) * T) / (sigma_G * np.sqrt(T))
    d2 = d1 - sigma_G * np.sqrt(T)
    return {'Price' : S * np.exp((b-r)*T) * stats.norm.cdf(d1) - K * np.exp(-r * T) * stats.norm.cdf(d2), 'Variance' : 0}

# %%
N_values = np.arange(10, int(1e5), 10000)
monte_carlo_geom = []
monte_carlo_geom_up = []
monte_carlo_geom_down = []
monte_carlo_exact = []
for i in range(len(N_values)):
    monte_carlo_geom.append(monte_carlo_asian_call_geometrique(S,K,T,r,sigma,d,N_values[i])['Price'])
    monte_carlo_geom_up.append(monte_carlo_asian_call_geometrique(S,K,T,r,sigma,d,N_values[i])['Price'] + np.sqrt(monte_carlo_asian_call_geometrique(S,K,T,r,sigma,d,N_values[i])['Variance']/N_values[i])*stats.norm.ppf(1-alpha/2))
    monte_carlo_geom_down.append(monte_carlo_asian_call_geometrique(S,K,T,r,sigma,d,N_values[i])['Price'] - np.sqrt(monte_carlo_asian_call_geometrique(S,K,T,r,sigma,d,N_values[i])['Variance']/N_values[i])*stats.norm.ppf(1-alpha/2))
    monte_carlo_exact.append(asiatique_geometrique_exact_value(S,K,T,r,sigma)['Price'])
plt.plot(N_values, monte_carlo_geom, color = 'r', linestyle = '-', label='Monte Carlo')
plt.fill_between(N_values, monte_carlo_geom_up, monte_carlo_geom_down, color='r', alpha=0.5, label = "Intervalle de confiance")
plt.plot(N_values, monte_carlo_exact, color = 'b', linestyle='-', label='Valeur exacte')
plt.xlabel("Nombre de simulations")
plt.ylabel("Prix de l'option")
plt.legend()
plt.grid()
plt.title("Comparaison de la valeur exacte et de la valeur estimée par Monte Carlo d'une option asiatique à moyenne géométrique")
plt.show()
